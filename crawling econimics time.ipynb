# %%
from scrapy.crawler import CrawlerProcess
from scrapy.utils.project import get_project_settings
from scrapy.linkextractors import LinkExtractor
from scrapy.contrib.spiders import CrawlSpider, Rule
from scrapy.item import Item, Field

class Item(Item):
    url= Field() #find all image urls in a web page 
    href= Field() #find all hyperlinks in a web page
    
class Spider(CrawlSpider):
    name = 'fox.com'
    allowed_domains = ['fox.com']
    start_urls = ['https://economictimes.indiatimes.com/magazines/panache/google-io-2018-live-updates/liveblog/64083274.cms?utm_source=facebook.com&utm_medium=Social&utm_campaign=ETFBPanache']
    rules = (
        Rule(LinkExtractor(), callback='parse_item'), # Extract Links
    )

    def parse_item(self, response):
        item = Item()
        item['url'] = []
        item['href'] = []
        for link in LinkExtractor(allow=()).extract_links(response):
            for imageurl in response.xpath('//img/@src').extract():
                item['url'].append(response.urljoin(imageurl))
            for link in response.xpath('//a/@href').extract():
                item['href'].append(response.urljoin(link))
            return item

#Run Scrapy from script   
process = CrawlerProcess(get_project_settings())
process.crawl(Spider)
process.start()
# Out:
# C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: ScrapyDeprecationWarning: Module `scrapy.contrib.spiders` is deprecated, use `scrapy.spiders` instead
#   after removing the cwd from sys.path.
# 2018-11-20 22:14:44 [scrapy.utils.log] INFO: Scrapy 1.5.1 started (bot: scrapybot)
# 2018-11-20 22:14:44 [scrapy.utils.log] INFO: Versions: lxml 4.2.5.0, libxml2 2.9.8, cssselect 1.0.3, parsel 1.5.1, w3lib 1.19.0, Twisted 18.7.0, Python 3.7.0 (default, Jun 28 2018, 08:04:48) [MSC v.1912 64 bit (AMD64)], pyOpenSSL 18.0.0 (OpenSSL 1.0.2p  14 Aug 2018), cryptography 2.3.1, Platform Windows-10-10.0.17134-SP0
# 2018-11-20 22:14:44 [scrapy.crawler] INFO: Overridden settings: {}
# 2018-11-20 22:14:44 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2018-11-20 22:14:44 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2018-11-20 22:14:44 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2018-11-20 22:14:44 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2018-11-20 22:14:44 [scrapy.core.engine] INFO: Spider opened
# 2018-11-20 22:14:44 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2018-11-20 22:14:44 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2018-11-20 22:14:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://economictimes.indiatimes.com/magazines/panache/google-io-2018-live-updates/liveblog/64083274.cms?utm_source=facebook.com&utm_medium=Social&utm_campaign=ETFBPanache> (referer: None)
# 2018-11-20 22:14:46 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'etapps.indiatimes.com': <GET https://etapps.indiatimes.com/gcm_webnotification.cms>
# 2018-11-20 22:14:46 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'market.android.com': <GET https://market.android.com/details?id=com.et.reader.activities>
# 2018-11-20 22:14:46 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'itunes.apple.com': <GET http://itunes.apple.com/us/app/the-economic-times/id474766725?ls=1&mt=8>
# 2018-11-20 22:14:46 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'play.google.com': <GET https://play.google.com/store/apps/details?id=com.et.wealth&hl=en>
# 2018-11-20 22:14:46 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'appworld.blackberry.com': <GET http://appworld.blackberry.com/webstore/content/54009?lang=en>
# 2018-11-20 22:14:46 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'ad.apsalar.com': <GET http://ad.apsalar.com/api/v1/ad?re=0&st=876405430363&h=b25110aca06ccea4b2efc9218dfb2a6a1bb46c89>
# 2018-11-20 22:14:46 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 
>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'navbharattimes.indiatimes.com': <GET http://navbharattimes.indiatimes.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'maharashtratimes.indiatimes.com': <GET http://maharashtratimes.indiatimes.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'vijaykarnataka.indiatimes.com': <GET http://vijaykarnataka.indiatimes.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'gogreenindia.co.in': <GET http://gogreenindia.co.in>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.adageindia.in': <GET http://www.adageindia.in/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'eisamay.indiatimes.com': <GET http://eisamay.indiatimes.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'in.ign.com': <GET http://in.ign.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'navgujaratsamay.indiatimes.com': <GET http://navgujaratsamay.indiatimes.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'timesofindia.indiatimes.com': <GET http://timesofindia.indiatimes.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'tamil.samayam.com': <GET http://tamil.samayam.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'telugu.samayam.com': <GET http://telugu.samayam.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.misskyra.com': <GET http://www.misskyra.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.bombaytimes.com': <GET http://www.bombaytimes.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.filmipop.com': <GET https://www.filmipop.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.baazinow.com': <GET https://www.baazinow.com/?utm_source=SEO&utm_campaign=ET>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.mxplayer.in': <GET https://www.mxplayer.in/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'timescity.com': <GET http://timescity.com>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'idiva.com': <GET http://idiva.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.zoomtv.in': <GET http://www.zoomtv.in/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'healthmeup.com': <GET http://healthmeup.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'luxpresso.com': <GET http://luxpresso.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.gadgetreview.com': <GET http://www.gadgetreview.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.hdfcbank.timescard.com': <GET http://www.hdfcbank.timescard.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'gaana.com': <GET http://gaana.com/newrelease/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'mensxp.com': <GET http://mensxp.com>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.happytrips.com': <GET http://www.happytrips.com/hotels>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'cricbuzz.com': <GET http://cricbuzz.com>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'recipes.timesofindia.com': <GET http://recipes.timesofindia.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.getsmartapp.com': <GET https://www.getsmartapp.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.itimes.com': <GET http://www.itimes.com>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.ads2book.com': <GET http://www.ads2book.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'shopping.indiatimes.com': <GET http://shopping.indiatimes.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.simplymarry.com': <GET http://www.simplymarry.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.astrospeak.com': <GET http://www.astrospeak.com>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.timesjobs.com': <GET http://www.timesjobs.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.techgig.com': <GET http://www.techgig.com>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.magicbricks.com': <GET http://www.magicbricks.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.zigwheels.com': <GET http://www.zigwheels.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.yolist.com': <GET http://www.yolist.com>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.timesofmoney.com': <GET http://www.timesofmoney.com/remittance/jsp/home.jsp>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.gadgetsnow.com': <GET http://www.gadgetsnow.com/mobile-phones>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.timesmobile.in': <GET http://www.timesmobile.in>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'property.magicbricks.com': <GET http://property.magicbricks.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'dineout.co.in': <GET http://dineout.co.in/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.coupondunia.in': <GET https://www.coupondunia.in/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.remit2india.com': <GET https://www.remit2india.com/sendmoneytoindia/homepage.jsp>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.in.techradar.com': <GET http://www.in.techradar.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.alivear.com': <GET http://www.alivear.com/>
# 2018-11-20 22:14:47 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'timescontent.com': <GET http://timescontent.com/>
# 2018-11-20 22:14:47 [scrapy.core.engine] INFO: Closing spider (finished)
# 2018-11-20 22:14:47 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 361,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 35153,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2018, 11, 20, 16, 44, 47, 737776),
#  'log_count/DEBUG': 88,
#  'log_count/INFO': 7,
#  'offsite/domains': 86,
#  'offsite/filtered': 254,
#  'request_depth_max': 1,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2018, 11, 20, 16, 44, 44, 856921)}
# 2018-11-20 22:14:47 [scrapy.core.engine] INFO: Spider closed (finished)
