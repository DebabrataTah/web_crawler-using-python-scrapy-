# %%
from scrapy.crawler import CrawlerProcess
from scrapy.utils.project import get_project_settings
from scrapy.linkextractors import LinkExtractor
from scrapy.contrib.spiders import CrawlSpider, Rule
from scrapy.item import Item, Field

class Item(Item):
    url= Field() #find all image urls in a web page 
    href= Field() #find all hyperlinks in a web page
    fonts = Field() #find all types of fonts in a web page
    
class Spider(CrawlSpider):
    name = 'doercity.com'
    allowed_domains = ['doercity.com']
    start_urls = ['https://doercity.com/']
    rules = (
        Rule(LinkExtractor(), callback='parse_item'), # Extract Links
    )

    def parse_item(self, response):
        item = Item()
        item['url'] = []
        item['href'] = []
       
       
        for link in LinkExtractor(allow=()).extract_links(response):
            for imageurl in response.xpath('//img/@src').extract():
                item['url'].append(response.urljoin(imageurl))
            for link in response.xpath('//a/@href').extract():
                item['href'].append(response.urljoin(link))
            
            return item.append(item)
        title = response.xpath('//h1/text()')[0].extract()
        print("title is: "+ start_urls)
        item['title'] = title
        return item

#Run Scrapy from script   
process = CrawlerProcess(get_project_settings())
process.crawl(Spider)
process.start()
# Out:
# C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: ScrapyDeprecationWarning: Module `scrapy.contrib.spiders` is deprecated, use `scrapy.spiders` instead
#   after removing the cwd from sys.path.
# 2018-11-23 14:09:37 [scrapy.utils.log] INFO: Scrapy 1.5.1 started (bot: scrapybot)
# 2018-11-23 14:09:37 [scrapy.utils.log] INFO: Versions: lxml 4.2.5.0, libxml2 2.9.8, cssselect 1.0.3, parsel 1.5.1, w3lib 1.19.0, Twisted 18.7.0, Python 3.7.0 (default, Jun 28 2018, 08:04:48) [MSC v.1912 64 bit (AMD64)], pyOpenSSL 18.0.0 (OpenSSL 1.0.2p  14 Aug 2018), cryptography 2.3.1, Platform Windows-10-10.0.17134-SP0
# 2018-11-23 14:09:37 [scrapy.crawler] INFO: Overridden settings: {}
# 2018-11-23 14:09:38 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2018-11-23 14:09:39 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2018-11-23 14:09:39 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2018-11-23 14:09:39 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2018-11-23 14:09:39 [scrapy.core.engine] INFO: Spider opened
# 2018-11-23 14:09:39 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2018-11-23 14:09:39 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6024
# 2018-11-23 14:09:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://doercity.com/> (referer: None)
# 2018-11-23 14:09:40 [scrapy.dupefilters] DEBUG: Filtered duplicate request: <GET https://doercity.com/project1004/#update> - no more duplicates will be shown (see DUPEFILTER_DEBUG to show all duplicates)
# 2018-11-23 14:09:40 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'twitter.com': <GET http://twitter.com/doerCity>
# 2018-11-23 14:09:40 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.instagram.com': <GET https://www.instagram.com/doercity/>
# 2018-11-23 14:09:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://doercity.com/project1004/> (referer: https://doercity.com/)
# 2018-11-23 14:09:40 [scrapy.core.scraper] ERROR: Spider error processing <GET https://doercity.com/project1004/> (referer: https://doercity.com/)
# Traceback (most recent call last):
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-f3f4f36f8d37>", line 32, in parse_item
#     return item.append(item)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\item.py", line 74, in __getattr__
#     raise AttributeError(name)
# AttributeError: append
# 2018-11-23 14:09:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://doercity.com/submission/> (referer: https://doercity.com/)
# 2018-11-23 14:09:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://doercity.com/about-doercity/> (referer: https://doercity.com/)
# 2018-11-23 14:09:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://doercity.com/> (referer: https://doercity.com/)
# 2018-11-23 14:09:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://doercity.com/terms-conditions/> (referer: https://doercity.com/)
# 2018-11-23 14:09:41 [scrapy.core.scraper] ERROR: Spider error processing <GET https://doercity.com/submission/> (referer: https://doercity.com/)
# Traceback (most recent call last):
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-f3f4f36f8d37>", line 32, in parse_item
#     return item.append(item)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\item.py", line 74, in __getattr__
#     raise AttributeError(name)
# AttributeError: append
# 2018-11-23 14:09:41 [scrapy.core.scraper] ERROR: Spider error processing <GET https://doercity.com/about-doercity/> (referer: https://doercity.com/)
# Traceback (most recent call last):
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-f3f4f36f8d37>", line 32, in parse_item
#     return item.append(item)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\item.py", line 74, in __getattr__
#     raise AttributeError(name)
# AttributeError: append
# 2018-11-23 14:09:41 [scrapy.core.scraper] ERROR: Spider error processing <GET https://doercity.com/> (referer: https://doercity.com/)
# Traceback (most recent call last):
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-f3f4f36f8d37>", line 32, in parse_item
#     return item.append(item)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\item.py", line 74, in __getattr__
#     raise AttributeError(name)
# AttributeError: append
# 2018-11-23 14:09:41 [scrapy.core.scraper] ERROR: Spider error processing <GET https://doercity.com/terms-conditions/> (referer: https://doercity.com/)
# Traceback (most recent call last):
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-f3f4f36f8d37>", line 32, in parse_item
#     return item.append(item)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\item.py", line 74, in __getattr__
#     raise AttributeError(name)
# AttributeError: append
# 2018-11-23 14:09:41 [scrapy.core.engine] INFO: Closing spider (finished)
# 2018-11-23 14:09:41 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 1481,
#  'downloader/request_count': 6,
#  'downloader/request_method_count/GET': 6,
#  'downloader/response_bytes': 42689,
#  'downloader/response_count': 6,
#  'downloader/response_status_count/200': 6,
#  'dupefilter/filtered': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2018, 11, 23, 8, 39, 41, 694344),
#  'log_count/DEBUG': 10,
#  'log_count/ERROR': 5,
#  'log_count/INFO': 7,
#  'offsite/domains': 2,
#  'offsite/filtered': 2,
#  'request_depth_max': 1,
#  'response_received_count': 6,
#  'scheduler/dequeued': 6,
#  'scheduler/dequeued/memory': 6,
#  'scheduler/enqueued': 6,
#  'scheduler/enqueued/memory': 6,
#  'spider_exceptions/AttributeError': 5,
#  'start_time': datetime.datetime(2018, 11, 23, 8, 39, 39, 792974)}
# 2018-11-23 14:09:41 [scrapy.core.engine] INFO: Spider closed (finished)
