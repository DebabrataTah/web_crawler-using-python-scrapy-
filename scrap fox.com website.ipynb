# %%
from scrapy.crawler import CrawlerProcess
from scrapy.utils.project import get_project_settings
from scrapy.linkextractors import LinkExtractor
from scrapy.contrib.spiders import CrawlSpider, Rule
from scrapy.item import Item, Field

class Item(Item):
    url= Field() #find all image urls in a web page 
    href= Field() #find all hyperlinks in a web page
    fonts = Field() #find all types of fonts in a web page
    
class Spider(CrawlSpider):
    name = 'fox.com'
    allowed_domains = ['fox.com']
    start_urls = ['https://www.fox.com/']
    rules = (
        Rule(LinkExtractor(), callback='parse_item'), # Extract Links
    )

    def parse_item(self, response):
        item = Item()
        item['url'] = []
        item['href'] = []
       
       
        for link in LinkExtractor(allow=()).extract_links(response):
            for imageurl in response.xpath('//img/@src').extract():
                item['url'].append(response.urljoin(imageurl))
            for link in response.xpath('//a/@href').extract():
                item['href'].append(response.urljoin(link))
            
            return item.append(item)
        title = response.xpath('//h1/text()')[0].extract()
        print("title is: "+ start_urls)
        item['title'] = title
        return item

#Run Scrapy from script   
process = CrawlerProcess(get_project_settings())
process.crawl(Spider)
process.start()
# Out:
# C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: ScrapyDeprecationWarning: Module `scrapy.contrib.spiders` is deprecated, use `scrapy.spiders` instead
#   after removing the cwd from sys.path.
# 2018-11-23 14:00:30 [scrapy.utils.log] INFO: Scrapy 1.5.1 started (bot: scrapybot)
# 2018-11-23 14:00:30 [scrapy.utils.log] INFO: Versions: lxml 4.2.5.0, libxml2 2.9.8, cssselect 1.0.3, parsel 1.5.1, w3lib 1.19.0, Twisted 18.7.0, Python 3.7.0 (default, Jun 28 2018, 08:04:48) [MSC v.1912 64 bit (AMD64)], pyOpenSSL 18.0.0 (OpenSSL 1.0.2p  14 Aug 2018), cryptography 2.3.1, Platform Windows-10-10.0.17134-SP0
# 2018-11-23 14:00:30 [scrapy.crawler] INFO: Overridden settings: {}
# 2018-11-23 14:00:31 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2018-11-23 14:00:32 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2018-11-23 14:00:32 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2018-11-23 14:00:32 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2018-11-23 14:00:32 [scrapy.core.engine] INFO: Spider opened
# 2018-11-23 14:00:32 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2018-11-23 14:00:32 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2018-11-23 14:00:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.fox.com/> (referer: None)
# 2018-11-23 14:00:35 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.facebook.com': <GET https://www.facebook.com/FOXTV>
# 2018-11-23 14:00:35 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'twitter.com': <GET https://twitter.com/FOXTV>
# 2018-11-23 14:00:35 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.foxcareers.com': <GET http://www.foxcareers.com>
# 2018-11-23 14:00:35 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'ask.foxnow.com': <GET https://ask.foxnow.com>
# 2018-11-23 14:00:35 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.fxnetworks.com': <GET http://www.fxnetworks.com/>
# 2018-11-23 14:00:35 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.simpsonsworld.com': <GET http://www.simpsonsworld.com/>
# 2018-11-23 14:00:35 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.nationalgeographic.com': <GET https://www.nationalgeographic.com/tv/>
# 2018-11-23 14:00:35 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.foxsports.com': <GET https://www.foxsports.com>
# 2018-11-23 14:00:35 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.foxnews.com': <GET http://www.foxnews.com>
# 2018-11-23 14:00:35 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.foxbusiness.com': <GET http://www.foxbusiness.com/index.html>
# 2018-11-23 14:00:35 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.foxmovies.com': <GET http://www.foxmovies.com/>
# 2018-11-23 14:00:35 [scrapy.spidermiddlewares.offsite] DEBUG: Filtered offsite request to 'www.21cf.com': <GET http://www.21cf.com/>
# 2018-11-23 14:00:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.fox.com/> (referer: https://www.fox.com/)
# 2018-11-23 14:00:35 [scrapy.dupefilters] DEBUG: Filtered duplicate request: <GET https://www.fox.com/article/privacy-policy-597bbe4f6603660022fa8689/#ads> - no more duplicates will be shown (see DUPEFILTER_DEBUG to show all duplicates)
# 2018-11-23 14:00:35 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.fox.com/> (referer: https://www.fox.com/)
# Traceback (most recent call last):
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-30e0bc8b9301>", line 32, in parse_item
#     return item.append(item)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\item.py", line 74, in __getattr__
#     raise AttributeError(name)
# AttributeError: append
# 2018-11-23 14:00:36 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://shop.fox.com/?ecid=PRF-FOX-400252&amp;pa=PRF-FOX-400252> from <GET http://shop.fox.com/?ecid=PRF-FOX-400252&amp;pa=PRF-FOX-400252>
# 2018-11-23 14:00:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.fox.com/shows/> (referer: https://www.fox.com/)
# 2018-11-23 14:00:36 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.fox.com/shows/> (referer: https://www.fox.com/)
# Traceback (most recent call last):
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-30e0bc8b9301>", line 32, in parse_item
#     return item.append(item)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\item.py", line 74, in __getattr__
#     raise AttributeError(name)
# AttributeError: append
# 2018-11-23 14:00:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.fox.com/live/> (referer: https://www.fox.com/)
# 2018-11-23 14:00:36 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.fox.com/live/> (referer: https://www.fox.com/)
# Traceback (most recent call last):
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-30e0bc8b9301>", line 32, in parse_item
#     return item.append(item)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\item.py", line 74, in __getattr__
#     raise AttributeError(name)
# AttributeError: append
# 2018-11-23 14:00:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.fox.com/article/-598b6e18311288001fef0f04/> (referer: https://www.fox.com/)
# 2018-11-23 14:00:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.fox.com/article/fox-affiliates-5987ae7f60ec65001f88ecdd/> (referer: https://www.fox.com/)
# 2018-11-23 14:00:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.fox.com/sitemap/> (referer: https://www.fox.com/)
# 2018-11-23 14:00:37 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.fox.com/article/-598b6e18311288001fef0f04/> (referer: https://www.fox.com/)
# Traceback (most recent call last):
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-30e0bc8b9301>", line 32, in parse_item
#     return item.append(item)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\item.py", line 74, in __getattr__
#     raise AttributeError(name)
# AttributeError: append
# 2018-11-23 14:00:37 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.fox.com/article/fox-affiliates-5987ae7f60ec65001f88ecdd/> (referer: https://www.fox.com/)
# Traceback (most recent call last):
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-30e0bc8b9301>", line 32, in parse_item
#     return item.append(item)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\item.py", line 74, in __getattr__
#     raise AttributeError(name)
# AttributeError: append
# 2018-11-23 14:00:37 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.fox.com/sitemap/> (referer: https://www.fox.com/)
# Traceback (most recent call last):
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-30e0bc8b9301>", line 32, in parse_item
#     return item.append(item)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\item.py", line 74, in __getattr__
#     raise AttributeError(name)
# AttributeError: append
# 2018-11-23 14:00:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://shop.fox.com/?ecid=PRF-FOX-400252&amp;pa=PRF-FOX-400252> (referer: None)
# 2018-11-23 14:00:37 [scrapy.core.scraper] ERROR: Spider error processing <GET https://shop.fox.com/?ecid=PRF-FOX-400252&amp;pa=PRF-FOX-400252> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-30e0bc8b9301>", line 32, in parse_item
#     return item.append(item)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\item.py", line 74, in __getattr__
#     raise AttributeError(name)
# AttributeError: append
# 2018-11-23 14:00:37 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://www.fox.com/sports/> (referer: https://www.fox.com/)
# 2018-11-23 14:00:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.fox.com/article/fox-networks-sites-and-services-terms-of-use-agreement-597bc239ef528f0026dc0316/> (referer: https://www.fox.com/)
# 2018-11-23 14:00:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.fox.com/article/fox-is-now-casting-59b2d8ce13320b0020eacf48/> (referer: https://www.fox.com/)
# 2018-11-23 14:00:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.fox.com/article/audio-description-5987a9810054d000205ff116/> (referer: https://www.fox.com/)
# 2018-11-23 14:00:37 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <404 https://www.fox.com/sports/>: HTTP status code is not handled or not allowed
# 2018-11-23 14:00:37 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.fox.com/article/fox-networks-sites-and-services-terms-of-use-agreement-597bc239ef528f0026dc0316/> (referer: https://www.fox.com/)
# Traceback (most recent call last):
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-30e0bc8b9301>", line 32, in parse_item
#     return item.append(item)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\item.py", line 74, in __getattr__
#     raise AttributeError(name)
# AttributeError: append
# 2018-11-23 14:00:37 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.fox.com/article/fox-is-now-casting-59b2d8ce13320b0020eacf48/> (referer: https://www.fox.com/)
# Traceback (most recent call last):
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-30e0bc8b9301>", line 32, in parse_item
#     return item.append(item)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\item.py", line 74, in __getattr__
#     raise AttributeError(name)
# AttributeError: append
# 2018-11-23 14:00:38 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.fox.com/article/audio-description-5987a9810054d000205ff116/> (referer: https://www.fox.com/)
# Traceback (most recent call last):
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-30e0bc8b9301>", line 32, in parse_item
#     return item.append(item)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\item.py", line 74, in __getattr__
#     raise AttributeError(name)
# AttributeError: append
# 2018-11-23 14:00:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.fox.com/article/fox-com-closed-captioning-5987a53b311288001fef0ef6/> (referer: https://www.fox.com/)
# 2018-11-23 14:00:38 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.fox.com/article/fox-com-closed-captioning-5987a53b311288001fef0ef6/> (referer: https://www.fox.com/)
# Traceback (most recent call last):
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-30e0bc8b9301>", line 32, in parse_item
#     return item.append(item)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\item.py", line 74, in __getattr__
#     raise AttributeError(name)
# AttributeError: append
# 2018-11-23 14:00:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.fox.com/article/privacy-policy-597bbe4f6603660022fa8689/> (referer: https://www.fox.com/)
# 2018-11-23 14:00:38 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.fox.com/article/privacy-policy-597bbe4f6603660022fa8689/> (referer: https://www.fox.com/)
# Traceback (most recent call last):
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-30e0bc8b9301>", line 32, in parse_item
#     return item.append(item)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\item.py", line 74, in __getattr__
#     raise AttributeError(name)
# AttributeError: append
# 2018-11-23 14:00:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.fox.com/movies/> (referer: https://www.fox.com/)
# 2018-11-23 14:00:40 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.fox.com/movies/> (referer: https://www.fox.com/)
# Traceback (most recent call last):
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\utils\defer.py", line 102, in iter_errback
#     yield next(it)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 30, in process_spider_output
#     for x in result:
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\spiders\crawl.py", line 76, in _parse_response
#     cb_res = callback(response, **cb_kwargs) or ()
#   File "<ipython-input-1-30e0bc8b9301>", line 32, in parse_item
#     return item.append(item)
#   File "C:\Users\Debabrata Tah\Anaconda3\lib\site-packages\scrapy\item.py", line 74, in __getattr__
#     raise AttributeError(name)
# AttributeError: append
# 2018-11-23 14:00:40 [scrapy.core.engine] INFO: Closing spider (finished)
# 2018-11-23 14:00:40 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 4262,
#  'downloader/request_count': 16,
#  'downloader/request_method_count/GET': 16,
#  'downloader/response_bytes': 1025329,
#  'downloader/response_count': 16,
#  'downloader/response_status_count/200': 14,
#  'downloader/response_status_count/301': 1,
#  'downloader/response_status_count/404': 1,
#  'dupefilter/filtered': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2018, 11, 23, 8, 30, 40, 51275),
#  'httperror/response_ignored_count': 1,
#  'httperror/response_ignored_status_count/404': 1,
#  'log_count/DEBUG': 30,
#  'log_count/ERROR': 13,
#  'log_count/INFO': 8,
#  'offsite/domains': 12,
#  'offsite/filtered': 12,
#  'request_depth_max': 1,
#  'response_received_count': 15,
#  'scheduler/dequeued': 16,
#  'scheduler/dequeued/memory': 16,
#  'scheduler/enqueued': 16,
#  'scheduler/enqueued/memory': 16,
#  'spider_exceptions/AttributeError': 13,
#  'start_time': datetime.datetime(2018, 11, 23, 8, 30, 32, 784666)}
# 2018-11-23 14:00:40 [scrapy.core.engine] INFO: Spider closed (finished)
